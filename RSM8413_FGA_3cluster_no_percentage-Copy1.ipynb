# %% [markdown]
# # 0. Import Packages

# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_samples, silhouette_score

import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn import model_selection
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

import warnings
warnings.filterwarnings("ignore")

# %%
# !pip install yellowbrick

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.cluster import KMeans
from yellowbrick.cluster import SilhouetteVisualizer

# %%
from sklearn.cluster import Birch

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn import linear_model

# %% [markdown]
# # Part 1

# %% [markdown]
# # 1. EDA

# %%
seed = 35
np.random.seed(seed)
original_df = pd.read_csv("CensusCanada2016Training.csv")
df = original_df.copy(deep=True)

# %%
df.head().T
# Out:
#                                                            0         1  \
# Total Population                                     4051.00   2329.00
# Total Households                                     1441.00   1026.00
# Median Household Income (Current Year $)            68242.12  88172.37
# Total Households For Period Of Construction          1441.00   1026.00
# Total Households For Period Of Construction Bui...    323.00    927.00
# Total Households For Period Of Construction Bui...    199.00     70.00
# Total Households For Period Of Construction Bui...     53.00     15.00
# Total Households For Period Of Construction Bui...    182.00      3.00
# Total Households For Period Of Construction Bui...    526.00      0.00
# Total Households For Structure Type Houses            911.00    792.00
# Total Households For Structure Type Apartment, ...    525.00    230.00
# Total Households For Structure Type Other Dwell...      5.00      4.00
# Total Households for Tenure                          1343.00    991.00
# Dwellings by Tenure Owner                             919.00    778.00
# Dwellings by Tenure Renter                            424.00    213.00
#
#                                                             2         3  \
# Total Population                                      5276.00   5967.00
# Total Households                                      2071.00   2203.00
# Median Household Income (Current Year $)            103853.38  82796.63
# Total Households For Period Of Construction           2071.00   2203.00
# Total Households For Period Of Construction Bui...       3.00    133.00
# Total Households For Period Of Construction Bui...     607.00   1695.00
# Total Households For Period Of Construction Bui...     567.00    248.00
# Total Households For Period Of Construction Bui...     651.00     79.00
# Total Households For Period Of Construction Bui...     106.00      0.00
# Total Households For Structure Type Houses            1418.00   1397.00
# Total Households For Structure Type Apartment, ...     652.00    806.00
# Total Households For Structure Type Other Dwell...       1.00      0.00
# Total Households for Tenure                           1903.00   2079.00
# Dwellings by Tenure Owner                             1522.00   1272.00
# Dwellings by Tenure Renter                             381.00    807.00
#
#                                                            4
# Total Population                                     4236.00
# Total Households                                     1419.00
# Median Household Income (Current Year $)            91648.22
# Total Households For Period Of Construction          1419.00
# Total Households For Period Of Construction Bui...      0.00
# Total Households For Period Of Construction Bui...      7.00
# Total Households For Period Of Construction Bui...    127.00
# Total Households For Period Of Construction Bui...    938.00
# Total Households For Period Of Construction Bui...    143.00
# Total Households For Structure Type Houses            914.00
# Total Households For Structure Type Apartment, ...    505.00
# Total Households For Structure Type Other Dwell...      0.00
# Total Households for Tenure                          1348.00
# Dwellings by Tenure Owner                            1186.00
# Dwellings by Tenure Renter                            162.00

# %%
df.columns
# Out:
# Index(['Total Population', 'Total Households',
#        'Median Household Income (Current Year $)',
#        'Total Households For Period Of Construction',
#        'Total Households For Period Of Construction Built Before 1961',
#        'Total Households For Period Of Construction Built Between 1961 And 1980',
#        'Total Households For Period Of Construction Built Between 1981 And 190',
#        'Total Households For Period Of Construction Built Between 1991 And 2000',
#        'Total Households For Period Of Construction Built Between 2001 And 2005',
#        'Total Households For Structure Type Houses',
#        'Total Households For Structure Type Apartment, Building Low And High Rise',
#        'Total Households For Structure Type Other Dwelling Types',
#        'Total Households for Tenure', 'Dwellings by Tenure Owner',
#        'Dwellings by Tenure Renter'],
#       dtype='object')

# %%
new_col_names = ['Population',
                'Households',
                'Median_income',
                'HH_construction',
                'HH_before_1961',
                'HH_1961_1980',
                'HH_1981_1990',
                'HH_1991_2000',
                'HH_2001_2005',
                'HH_houses',
                'HH_apt_LH_rise',
                'HH_dwelling_other',
                'HH_tenure',
                'Dwellings_owner',
                'Dwellings_renter']

# %%
df.columns = new_col_names
df.head()
# Out:
#    Population  Households  Median_income  HH_construction  HH_before_1961  \
# 0        4051        1441       68242.12             1441             323
# 1        2329        1026       88172.37             1026             927
# 2        5276        2071      103853.38             2071               3
# 3        5967        2203       82796.63             2203             133
# 4        4236        1419       91648.22             1419               0
#
#    HH_1961_1980  HH_1981_1990  HH_1991_2000  HH_2001_2005  HH_houses  \
# 0           199            53           182           526        911
# 1            70            15             3             0        792
# 2           607           567           651           106       1418
# 3          1695           248            79             0       1397
# 4             7           127           938           143        914
#
#    HH_apt_LH_rise  HH_dwelling_other  HH_tenure  Dwellings_owner  \
# 0             525                  5       1343              919
# 1             230                  4        991              778
# 2             652                  1       1903             1522
# 3             806                  0       2079             1272
# 4             505                  0       1348             1186
#
#    Dwellings_renter
# 0               424
# 1               213
# 2               381
# 3               807
# 4               162

# %%
df.shape
# Out:
# (5000, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Population         5000 non-null   int64
#  1   Households         5000 non-null   int64
#  2   Median_income      5000 non-null   float64
#  3   HH_construction    5000 non-null   int64
#  4   HH_before_1961     5000 non-null   int64
#  5   HH_1961_1980       5000 non-null   int64
#  6   HH_1981_1990       5000 non-null   int64
#  7   HH_1991_2000       5000 non-null   int64
#  8   HH_2001_2005       5000 non-null   int64
#  9   HH_houses          5000 non-null   int64
#  10  HH_apt_LH_rise     5000 non-null   int64
#  11  HH_dwelling_other  5000 non-null   int64
#  12  HH_tenure          5000 non-null   int64
#  13  Dwellings_owner    5000 non-null   int64
#  14  Dwellings_renter   5000 non-null   int64
# dtypes: float64(1), int64(14)
# memory usage: 586.1 KB

# %%
df.describe()
# Out:
#          Population    Households  Median_income  HH_construction  \
# count   5000.000000   5000.000000    5000.000000      5000.000000
# mean    4866.967400   1927.776200   77241.071536      1927.776200
# std     2491.841571    974.811432   33371.567357       974.811432
# min        0.000000      0.000000       0.000000         0.000000
# 25%     3289.750000   1333.750000   53040.835000      1333.750000
# 50%     4655.000000   1825.000000   76206.780000      1825.000000
# 75%     6233.750000   2428.250000   95438.495000      2428.250000
# max    30789.000000  15388.000000  669559.560000     15388.000000
#
#        HH_before_1961  HH_1961_1980  HH_1981_1990  HH_1991_2000  HH_2001_2005  \
# count     5000.000000   5000.000000    5000.00000    5000.00000   5000.000000
# mean       386.510600    555.437800     260.48240     237.92820    138.595600
# std        416.908471    448.327845     257.86717     265.43332    221.809214
# min          0.000000      0.000000       0.00000       0.00000      0.000000
# 25%         47.000000    192.000000      74.00000      58.00000     17.000000
# 50%        238.000000    470.000000     181.00000     143.00000     52.000000
# 75%        613.000000    830.000000     369.00000     325.00000    157.000000
# max       2411.000000   3547.000000    1740.00000    2360.00000   2262.000000
#
#         HH_houses  HH_apt_LH_rise  HH_dwelling_other     HH_tenure  \
# count  5000.00000     5000.000000        5000.000000   5000.000000
# mean   1134.79180      777.188400          15.796000   1810.954800
# std     812.09222      891.021549          62.949187    897.938845
# min       0.00000        0.000000           0.000000      0.000000
# 25%     534.00000      146.000000           0.000000   1258.000000
# 50%    1076.00000      487.000000           2.000000   1724.500000
# 75%    1592.00000     1119.000000           6.000000   2281.250000
# max    9123.00000    15248.000000        1378.000000  11891.000000
#
#        Dwellings_owner  Dwellings_renter
# count       5000.00000       5000.000000
# mean        1182.21140        628.155800
# std          710.51703        594.295093
# min            0.00000          0.000000
# 25%          687.00000        201.000000
# 50%         1112.00000        456.000000
# 75%         1570.00000        879.000000
# max         8628.00000       6813.000000

# %%
for column in df.columns:
    if column != 'Median_income':
        df.plot(kind = "scatter", x = 'Median_income', y = column, alpha=0.1)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
# correlation heatmap
plt.figure(figsize=(25, 15))
plt.suptitle('Correlations', fontsize = 30, color= 'teal')
corr = df.corr()
sns.heatmap(corr, annot=True)
plt.show()

# %%
df.plot('Population', "Households", kind='scatter', alpha=0.1)
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='Population', ylabel='Households'>

# %%
df['Population'].hist(bins=40)
# Out:
# <AxesSubplot:>

# %%
df[['Population',
                'Households',
                'Median_income',
                'HH_before_1961',
                'HH_1961_1980',
                'HH_1981_1990',
                'HH_1991_2000',
                'HH_2001_2005',
                'HH_houses',
                'HH_apt_LH_rise',
                'HH_dwelling_other',
                'HH_tenure',
                'Dwellings_owner',
                'Dwellings_renter']].hist(bins=30, sharex=False, sharey=False, xlabelsize=10, ylabelsize=10, figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'Population'}>,
#         <AxesSubplot:title={'center':'Households'}>,
#         <AxesSubplot:title={'center':'Median_income'}>,
#         <AxesSubplot:title={'center':'HH_before_1961'}>],
#        [<AxesSubplot:title={'center':'HH_1961_1980'}>,
#         <AxesSubplot:title={'center':'HH_1981_1990'}>,
#         <AxesSubplot:title={'center':'HH_1991_2000'}>,
#         <AxesSubplot:title={'center':'HH_2001_2005'}>],
#        [<AxesSubplot:title={'center':'HH_houses'}>,
#         <AxesSubplot:title={'center':'HH_apt_LH_rise'}>,
#         <AxesSubplot:title={'center':'HH_dwelling_other'}>,
#         <AxesSubplot:title={'center':'HH_tenure'}>],
#        [<AxesSubplot:title={'center':'Dwellings_owner'}>,
#         <AxesSubplot:title={'center':'Dwellings_renter'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
df[df['Population']<500]
# Out:
#       Population  Households  Median_income  HH_construction  HH_before_1961  \
# 36           384          98       54750.00               98               3
# 62            41          22       54083.50               22               0
# 78           330         125       85909.09              125               3
# 98             3           2      100000.00                2               0
# 156          260         123       31356.32              123              83
# ...          ...         ...            ...              ...             ...
# 4737         172          48       75000.00               48              15
# 4800           2           1       47045.32                1               1
# 4922          20           8       80000.00                8               2
# 4962         341          95      119851.93               95               0
# 4982          29          11       47656.25               11               3
#
#       HH_1961_1980  HH_1981_1990  HH_1991_2000  HH_2001_2005  HH_houses  \
# 36              29            17            23             9         73
# 62               0             0            14             4         22
# 78              33            25            27            11        110
# 98               1             0             0             0          2
# 156             12             0            11            16         24
# ...            ...           ...           ...           ...        ...
# 4737            14             5             4             2         34
# 4800             0             0             0             0          0
# 4922             3             1             1             0          8
# 4962            21            16            32             0         90
# 4982             1             1             2             0         11
#
#       HH_apt_LH_rise  HH_dwelling_other  HH_tenure  Dwellings_owner  \
# 36                 0                 25        101               75
# 62                 0                  0         21                5
# 78                10                  5        119              119
# 98                 0                  0          6                5
# 156               99                  0        125               38
# ...              ...                ...        ...              ...
# 4737              14                  0          0                0
# 4800               0                  1          1                0
# 4922               0                  0          8                5
# 4962               5                  0         90               60
# 4982               0                  0          7                2
#
#       Dwellings_renter
# 36                  11
# 62                   0
# 78                   0
# 98                   1
# 156                 87
# ...                ...
# 4737                 0
# 4800                 1
# 4922                 3
# 4962                20
# 4982                 1
#
# [129 rows x 15 columns]

# %% [markdown]
# # 2. New Feature Engineering

# %%
# average household size, drop construction, percentages for periods, percentage for types
# Total Households NOT for Tenure
# percentages for owner and renter

# %%
# drop rows with households equal 0. 
df.drop(df[df['Households']==0].index, inplace=True)

# %%
# df['Avg_HH_size'] = df['Population']/df['Households']

# # df['Pctg_before_1961'] = df['HH_before_1961']/df['Households']
# # df['Pctg_1961_1980'] = df['HH_1961_1980']/df['Households']
# # df['Pctg_1981_1990'] = df['HH_1981_1990']/df['Households']
# # df['Pctg_1991_2000'] = df['HH_1991_2000']/df['Households']
# # df['Pctg_2001_2005'] = df['HH_2001_2005']/df['Households']

# #Bucket construction before 2000
# df['Total_before_2005'] = (df['HH_1991_2000'] + df['HH_1981_1990'] + df['HH_1961_1980'] + df['HH_before_1961'] + df['HH_2001_2005'])/df['Households']




# # df['Pctg_after_2005'] = (df['Households']-df['HH_before_1961']-df['HH_1961_1980']-df['HH_1981_1990']-df['HH_1991_2000']-df['HH_2001_2005'])/df['Households']


# df['HH_houses'] = df['HH_houses']/df['Households']
# df['HH_apt_LH_rise'] = df['HH_apt_LH_rise']/df['Households']
# df['HH_dwelling_other'] = df['HH_dwelling_other']/df['Households']

# df['HH_not_tenure'] = 1-df['HH_tenure']/df['Households']
# df['Dwellings_owner'] = df['Dwellings_owner']/df['HH_tenure']
# df['Dwellings_renter'] = df['Dwellings_renter']/df['HH_tenure']

# %%
df['Avg_HH_size'] = df['Population']/df['Households']

# df['Pctg_before_1961'] = df['HH_before_1961']/df['Households']
# df['Pctg_1961_1980'] = df['HH_1961_1980']/df['Households']
# df['Pctg_1981_1990'] = df['HH_1981_1990']/df['Households']
# df['Pctg_1991_2000'] = df['HH_1991_2000']/df['Households']
# df['Pctg_2001_2005'] = df['HH_2001_2005']/df['Households']

#Bucket construction before 2000
df['Total_before_2005'] = df['HH_1981_1990'] + df['HH_1961_1980'] + df['HH_before_1961']

# df['Pctg_after_2005'] = (df['Households']-df['HH_before_1961']-df['HH_1961_1980']-df['HH_1981_1990']-df['HH_1991_2000']-df['HH_2001_2005'])/df['Households']

df['HH_not_tenure'] = df['Households']-df['HH_tenure']

# %%
# clean nan in rows with HH_tenure.
df.loc[np.isnan(df['Dwellings_owner']), ['Dwellings_owner', 'Dwellings_renter']] = 0

# %%
# drop HH_construction because it's the same as households
dropped_columns = ['HH_construction', 'Households', 'HH_before_1961', 'HH_1961_1980', 'HH_1981_1990',
                  'HH_1991_2000', 'HH_2001_2005', 'HH_tenure']
df.drop(columns=dropped_columns, inplace=True)

# %%
df.head()
# Out:
#    Population  Median_income  HH_houses  HH_apt_LH_rise  HH_dwelling_other  \
# 0        4051       68242.12        911             525                  5
# 1        2329       88172.37        792             230                  4
# 2        5276      103853.38       1418             652                  1
# 3        5967       82796.63       1397             806                  0
# 4        4236       91648.22        914             505                  0
#
#    Dwellings_owner  Dwellings_renter  Avg_HH_size  Total_before_2005  \
# 0              919               424     2.811242                575
# 1              778               213     2.269981               1012
# 2             1522               381     2.547562               1177
# 3             1272               807     2.708579               2076
# 4             1186               162     2.985201                134
#
#    HH_not_tenure
# 0             98
# 1             35
# 2            168
# 3            124
# 4             71

# %%
# correlation heatmap
plt.figure(figsize=(25, 15))
plt.suptitle('Correlations', fontsize = 30, color= 'teal')
corr = df.corr()
sns.heatmap(corr, annot=True)
plt.show()

# %%
# drop HH_construction because it's the same as households
dropped_columns = ['HH_houses', 'Dwellings_owner']
df.drop(columns=dropped_columns, inplace=True)

# %%
# correlation heatmap
plt.figure(figsize=(25, 15))
plt.suptitle('Correlations', fontsize = 30, color= 'teal')
corr = df.corr()
sns.heatmap(corr, annot=True)
plt.show()

# %%
df.columns
# Out:
# Index(['Population', 'Median_income', 'HH_apt_LH_rise', 'HH_dwelling_other',
#        'Dwellings_renter', 'Avg_HH_size', 'Total_before_2005',
#        'HH_not_tenure'],
#       dtype='object')

# %%
# drop Dwellings_owner, HH_houses for high collinearity
df_x = df[['Population', 'Avg_HH_size', 'Total_before_2005',
       'HH_apt_LH_rise', 'HH_dwelling_other',
       'HH_not_tenure', 'Dwellings_renter']].copy(deep=True)
df_y = df[['Median_income']].copy(deep=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4980 entries, 0 to 4999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Population         4980 non-null   int64
#  1   Median_income      4980 non-null   float64
#  2   HH_apt_LH_rise     4980 non-null   int64
#  3   HH_dwelling_other  4980 non-null   int64
#  4   Dwellings_renter   4980 non-null   int64
#  5   Avg_HH_size        4980 non-null   float64
#  6   Total_before_2005  4980 non-null   int64
#  7   HH_not_tenure      4980 non-null   int64
# dtypes: float64(2), int64(6)
# memory usage: 350.2 KB

# %% [markdown]
# # 3. Clustering

# %%
# Scaling
kmeans_scaler = StandardScaler()
kmeans_scaler.fit(df)
scaled_df = kmeans_scaler.transform(df)
# scaled_df=df

# %%
# scaling df
scaled_df = pd.DataFrame(scaled_df)
scaled_df.columns = df.columns
scaled_df.head()
# Out:
#    Population  Median_income  HH_apt_LH_rise  HH_dwelling_other  \
# 0   -0.337217      -0.281469       -0.286429          -0.172205
# 1   -1.032272       0.321136       -0.617386          -0.188062
# 2    0.157233       0.795263       -0.143949          -0.235635
# 3    0.436143       0.158597        0.028822          -0.251493
# 4   -0.262545       0.426231       -0.308867          -0.251493
#
#    Dwellings_renter  Avg_HH_size  Total_before_2005  HH_not_tenure
# 0         -0.347891     0.254957          -0.896479      -0.166224
# 1         -0.703056    -0.334440          -0.276858      -0.709086
# 2         -0.420270    -0.032173          -0.042905       0.436956
# 3          0.296792     0.143164           1.231783       0.057814
# 4         -0.788901     0.444386          -1.521771      -0.398879

# %% [markdown]
# ## 3.1 KMeans Clustering

# %%
cluster_number = 3

# %%
df_K = df.copy(deep=True)

# %%
# visualize inertias

ks = range(1,20)
inertias = []

for k in ks:
    # Create a KMeans instance with k clusters: model
    
    np.random.seed(seed)
    
    model = KMeans(n_clusters = k)
    
    # Fit model to samples
    model.fit(scaled_df)
    
    # Append the inertia to the list of inertias
    inertias.append(model.inertia_)
    
# Plot ks vs inertias
plt.plot(ks, inertias, '-o')
plt.xlabel('number of clusters, k')
plt.ylabel('inertia')
plt.xticks(ks)
plt.show()

# %%
# visualize silhouette_score

ks = range(2,15)
silhouette_score_list = []
for k in ks:
    
    np.random.seed(seed)
    
    # Create a KMeans instance with k clusters: model
    model = KMeans(n_clusters = k)
    
    # Fit model to samples
    model.fit_predict(scaled_df)
    
    # Append the inertia to the list of inertias
    s_score = silhouette_score(scaled_df, model.labels_, metric='euclidean')
    silhouette_score_list.append(model.inertia_)
    
    
# Plot ks vs inertias
plt.plot(ks, silhouette_score_list, '-o')
plt.xlabel('number of clusters, k')
plt.ylabel('silhouette score')
plt.xticks(ks)
plt.show()

# %%
# visualize silhouette_sample_score, k=4 is selected


fig, ax = plt.subplots(7, 2, figsize=(10,30))
for k in range(2,15):
    
    np.random.seed(84) 
#     35, 73,

    km = KMeans(n_clusters=k)
    q, mod = divmod(k, 2)

    visualizer = SilhouetteVisualizer(km, colors='yellowbrick', ax=ax[q-1][mod])
    visualizer.fit(scaled_df)

# %%
# k=3 is selected

np.random.seed(seed)

model = KMeans(n_clusters = cluster_number)

# Fit model to scaled_df
model.fit_predict(scaled_df)


df_K['Cluster'] = model.labels_

# %%
model.labels_
# Out:
# array([2, 2, 0, ..., 2, 2, 0])

# %%
df_K.columns
# Out:
# Index(['Population', 'Median_income', 'HH_apt_LH_rise', 'HH_dwelling_other',
#        'Dwellings_renter', 'Avg_HH_size', 'Total_before_2005', 'HH_not_tenure',
#        'Cluster'],
#       dtype='object')

# %%
# plot value counts of each numerical column
bins = 35
col_list = list(df_K.columns)
plt.style.use('default')

fig, axs = plt.subplots(len(col_list)-1, figsize=(7, 60))
# plt.subplots_adjust(hspace=1)
for col in col_list:
    if col != "Cluster":
        for n in range(0,cluster_number):
            axs[col_list.index(col)].hist(df_K[df_K['Cluster']==n][col], bins=bins, alpha=0.4, 
                                          label=n, density=False)
        axs[col_list.index(col)].legend(loc="upper right")
        axs[col_list.index(col)].set_xlabel(col)
        axs[col_list.index(col)].set_ylabel('Count')
    
fig.show()

# %%
df_K.describe()
# Out:
#          Population  Median_income  HH_apt_LH_rise  HH_dwelling_other  \
# count   4980.000000    4980.000000     4980.000000        4980.000000
# mean    4886.455622   77551.276643      780.309639          15.859438
# std     2477.749372   33076.778994      891.444026          63.067512
# min        2.000000   11334.980000        0.000000           0.000000
# 25%     3305.000000   53201.355000      148.000000           0.000000
# 50%     4663.500000   76328.300000      490.000000           2.000000
# 75%     6242.500000   95554.435000     1120.250000           6.000000
# max    30789.000000  669559.560000    15248.000000        1378.000000
#
#        Dwellings_renter  Avg_HH_size  Total_before_2005  HH_not_tenure  \
# count       4980.000000  4980.000000        4980.000000    4980.000000
# mean         630.678514     2.577107        1207.259839     117.290562
# std          594.149831     0.918424         705.341299     116.063251
# min            0.000000     1.000000           0.000000     -57.000000
# 25%          202.750000     2.217237         729.250000      55.000000
# 50%          458.000000     2.539718        1214.000000      98.000000
# 75%          880.250000     2.850387        1667.000000     150.000000
# max         6813.000000    49.250000        5407.000000    3497.000000
#
#            Cluster
# count  4980.000000
# mean      1.205622
# std       0.847647
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       2.000000
# max       2.000000

# %%
# count summary
count_summary = df_K.describe().loc[['count']]

for n in range(0,cluster_number):
    index = pd.Index([n])
    temp = df_K[df_K['Cluster']==n].describe().loc[['count']].set_index(index)
    count_summary = pd.concat([count_summary, temp])

count_summary
# Out:
#        Population  Median_income  HH_apt_LH_rise  HH_dwelling_other  \
# count      4980.0         4980.0          4980.0             4980.0
# 0          1382.0         1382.0          1382.0             1382.0
# 1          1192.0         1192.0          1192.0             1192.0
# 2          2406.0         2406.0          2406.0             2406.0
#
#        Dwellings_renter  Avg_HH_size  Total_before_2005  HH_not_tenure  \
# count            4980.0       4980.0             4980.0         4980.0
# 0                1382.0       1382.0             1382.0         1382.0
# 1                1192.0       1192.0             1192.0         1192.0
# 2                2406.0       2406.0             2406.0         2406.0
#
#        Cluster
# count   4980.0
# 0       1382.0
# 1       1192.0
# 2       2406.0

# %%
# mean summary
mean_summary = df_K.describe().loc[['mean']]

for n in range(0,cluster_number):
    index = pd.Index([n])
    temp = df_K[df_K['Cluster']==n].describe().loc[['mean']].set_index(index)
    mean_summary = pd.concat([mean_summary, temp])

mean_summary
# Out:
#        Population  Median_income  HH_apt_LH_rise  HH_dwelling_other  \
# mean  4886.455622   77551.276643      780.309639          15.859438
# 0     6839.769175  107154.212323      350.942836          29.078148
# 1     5870.044463   53426.437341     1945.725671           9.709732
# 2     3277.179967   72499.552344      449.556941          11.313383
#
#       Dwellings_renter  Avg_HH_size  Total_before_2005  HH_not_tenure  \
# mean        630.678514     2.577107        1207.259839     117.290562
# 0           326.968886     3.048052         948.361795     165.066570
# 1          1447.806208     2.180605        1942.608221     170.901846
# 2           400.300499     2.503036         991.657938      63.287614
#
#        Cluster
# mean  1.205622
# 0     0.000000
# 1     1.000000
# 2     2.000000

# %%
# cluster count bar chart
temp = count_summary.iloc[1:,:]['Population']
fig, ax = plt.subplots(1, figsize=(5, 4))
ax.bar(temp.index.astype(str), temp)
ax.set_xlabel('Cluster')
ax.set_ylabel('Count')
fig.show()

# %%
fig, axs = plt.subplots(len(col_list)-1, figsize=(5, 50))
# plt.subplots_adjust(hspace=1)
for col in col_list:
    if col != "Cluster":

        axs[col_list.index(col)].bar(mean_summary[col].index.astype(str), mean_summary[col], alpha=0.4)
        axs[col_list.index(col)].set_xlabel(col)
        axs[col_list.index(col)].set_ylabel('Mean Value')
    
fig.show()

# %% [markdown]
# ## 3.2 Birch Clustering

# %%
df_birch = df.copy(deep=True)

# %%
np.random.seed(seed) 
brc = Birch(n_clusters=cluster_number)
brc_labels = brc.fit_predict(scaled_df)

df_birch['Cluster'] = brc_labels

# %%
# plot value counts of each numerical column
bins = 35
col_list = list(df_birch.columns)
plt.style.use('default')

fig, axs = plt.subplots(len(col_list)-1, figsize=(7, 60))
# plt.subplots_adjust(hspace=1)
for col in col_list:
    if col != "Cluster":
        for n in range(0,cluster_number):
            axs[col_list.index(col)].hist(df_birch[df_birch['Cluster']==n][col], bins=bins, alpha=0.4, 
                                          label=n, density=False)
        axs[col_list.index(col)].legend(loc="upper right")
        axs[col_list.index(col)].set_xlabel(col)
        axs[col_list.index(col)].set_ylabel('Count')
    
fig.show()

# %%
df_birch.describe()
# Out:
#          Population  Median_income  HH_apt_LH_rise  HH_dwelling_other  \
# count   4980.000000    4980.000000     4980.000000        4980.000000
# mean    4886.455622   77551.276643      780.309639          15.859438
# std     2477.749372   33076.778994      891.444026          63.067512
# min        2.000000   11334.980000        0.000000           0.000000
# 25%     3305.000000   53201.355000      148.000000           0.000000
# 50%     4663.500000   76328.300000      490.000000           2.000000
# 75%     6242.500000   95554.435000     1120.250000           6.000000
# max    30789.000000  669559.560000    15248.000000        1378.000000
#
#        Dwellings_renter  Avg_HH_size  Total_before_2005  HH_not_tenure  \
# count       4980.000000  4980.000000        4980.000000    4980.000000
# mean         630.678514     2.577107        1207.259839     117.290562
# std          594.149831     0.918424         705.341299     116.063251
# min            0.000000     1.000000           0.000000     -57.000000
# 25%          202.750000     2.217237         729.250000      55.000000
# 50%          458.000000     2.539718        1214.000000      98.000000
# 75%          880.250000     2.850387        1667.000000     150.000000
# max         6813.000000    49.250000        5407.000000    3497.000000
#
#            Cluster
# count  4980.000000
# mean      0.266265
# std       0.442503
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       2.000000

# %%
# count summary
count_summary_birch = df_birch.describe().loc[['count']]

for n in range(0,cluster_number):
    index = pd.Index([n])
    temp = df_birch[df_birch['Cluster']==n].describe().loc[['count']].set_index(index)
    count_summary_birch = pd.concat([count_summary_birch, temp])

count_summary_birch
# Out:
#        Population  Median_income  HH_apt_LH_rise  HH_dwelling_other  \
# count      4980.0         4980.0          4980.0             4980.0
# 0          3655.0         3655.0          3655.0             3655.0
# 1          1324.0         1324.0          1324.0             1324.0
# 2             1.0            1.0             1.0                1.0
#
#        Dwellings_renter  Avg_HH_size  Total_before_2005  HH_not_tenure  \
# count            4980.0       4980.0             4980.0         4980.0
# 0                3655.0       3655.0             3655.0         3655.0
# 1                1324.0       1324.0             1324.0         1324.0
# 2                   1.0          1.0                1.0            1.0
#
#        Cluster
# count   4980.0
# 0       3655.0
# 1       1324.0
# 2          1.0

# %%
# mean summary
mean_summary_birch = df_birch.describe().loc[['mean']]

for n in range(0,cluster_number):
    index = pd.Index([n])
    temp = df_birch[df_birch['Cluster']==n].describe().loc[['mean']].set_index(index)
    mean_summary_birch = pd.concat([mean_summary_birch, temp])

mean_summary_birch
# Out:
#        Population  Median_income  HH_apt_LH_rise  HH_dwelling_other  \
# mean  4886.455622   77551.276643      780.309639          15.859438
# 0     4784.003830   87409.626856      403.237483          18.575923
# 1     5172.674471   50357.380302     1821.828550           8.372356
# 2      394.000000   50000.000000        8.000000           0.000000
#
#       Dwellings_renter  Avg_HH_size  Total_before_2005  HH_not_tenure  \
# mean        630.678514     2.577107        1207.259839     117.290562
# 0           360.160328     2.729688         983.168263     107.568263
# 1          1377.938066     2.120645        1826.789275     144.216012
# 2             3.000000    49.250000           5.000000       3.000000
#
#        Cluster
# mean  0.266265
# 0     0.000000
# 1     1.000000
# 2     2.000000

# %%
# cluster count bar chart
temp = count_summary_birch.iloc[1:,:]['Population']
fig, ax = plt.subplots(1, figsize=(5, 4))
ax.bar(temp.index.astype(str), temp)
ax.set_xlabel('Cluster')
ax.set_ylabel('Count')
fig.show()

# %%
fig, axs = plt.subplots(len(col_list)-1, figsize=(5, 50))
# plt.subplots_adjust(hspace=1)
for col in col_list:
    if col != "Cluster":

        axs[col_list.index(col)].bar(mean_summary_birch[col].index.astype(str), mean_summary_birch[col], alpha=0.4)
        axs[col_list.index(col)].set_xlabel(col)
        axs[col_list.index(col)].set_ylabel('Mean Value')
    
fig.show()

# %% [markdown]
# # Part 2

# %%
scaled_no_inc_df = scaled_df.drop(columns=['Median_income'])
df_K_p2 = df.copy(deep=True)

# %%
scaled_no_inc_df.head()
# Out:
#    Population  HH_apt_LH_rise  HH_dwelling_other  Dwellings_renter  \
# 0   -0.337217       -0.286429          -0.172205         -0.347891
# 1   -1.032272       -0.617386          -0.188062         -0.703056
# 2    0.157233       -0.143949          -0.235635         -0.420270
# 3    0.436143        0.028822          -0.251493          0.296792
# 4   -0.262545       -0.308867          -0.251493         -0.788901
#
#    Avg_HH_size  Total_before_2005  HH_not_tenure
# 0     0.254957          -0.896479      -0.166224
# 1    -0.334440          -0.276858      -0.709086
# 2    -0.032173          -0.042905       0.436956
# 3     0.143164           1.231783       0.057814
# 4     0.444386          -1.521771      -0.398879

# %% [markdown]
# # 3.3 KMeans without income data

# %%
# visualize inertias

ks = range(1,20)
inertias = []

for k in ks:
    # Create a KMeans instance with k clusters: model
    
    np.random.seed(seed)
    
    model = KMeans(n_clusters = k)
    
    # Fit model to samples
    model.fit(scaled_no_inc_df)
    
    # Append the inertia to the list of inertias
    inertias.append(model.inertia_)
    
# Plot ks vs inertias
plt.plot(ks, inertias, '-o')
plt.xlabel('number of clusters, k')
plt.ylabel('inertia')
plt.xticks(ks)
plt.show()

# %%
# visualize silhouette_score

ks = range(2,15)
silhouette_score_list = []
for k in ks:
    
    np.random.seed(seed)
    
    # Create a KMeans instance with k clusters: model
    model = KMeans(n_clusters = k)
    
    # Fit model to samples
    model.fit_predict(scaled_no_inc_df)
    
    # Append the inertia to the list of inertias
    s_score = silhouette_score(scaled_no_inc_df, model.labels_, metric='euclidean')
    silhouette_score_list.append(model.inertia_)
    
    
# Plot ks vs inertias
plt.plot(ks, silhouette_score_list, '-o')
plt.xlabel('number of clusters, k')
plt.ylabel('silhouette score')
plt.xticks(ks)
plt.show()

# %%
# visualize silhouette_sample_score, k=4 is selected


fig, ax = plt.subplots(7, 2, figsize=(10,30))
for k in range(2,15):
    
    np.random.seed(35) 
#     35, 73,

    km = KMeans(n_clusters=k)
    q, mod = divmod(k, 2)

    visualizer = SilhouetteVisualizer(km, colors='yellowbrick', ax=ax[q-1][mod])
    visualizer.fit(scaled_no_inc_df)

# %%
# k=2 is selected

np.random.seed(seed)

model = KMeans(n_clusters = cluster_number)

# Fit model to scaled_df
model.fit(scaled_no_inc_df)

# Keep for predicting
K_Mean_for_pred = model
model.predict(scaled_no_inc_df)


df_K_p2['Cluster'] = model.labels_

# %%
model.labels_
# Out:
# array([0, 0, 1, ..., 1, 0, 1])

# %%
df_K_p2.columns
# Out:
# Index(['Population', 'Median_income', 'HH_apt_LH_rise', 'HH_dwelling_other',
#        'Dwellings_renter', 'Avg_HH_size', 'Total_before_2005', 'HH_not_tenure',
#        'Cluster'],
#       dtype='object')

# %%
# plot value counts of each numerical column
bins = 35
col_list = list(df_K_p2.columns)
plt.style.use('default')

fig, axs = plt.subplots(len(col_list)-1, figsize=(7, 60))
# plt.subplots_adjust(hspace=1)
for col in col_list:
    if col != "Cluster":
        for n in range(0,cluster_number):
            axs[col_list.index(col)].hist(df_K_p2[df_K_p2['Cluster']==n][col], bins=bins, alpha=0.4, 
                                          label=n, density=False)
        axs[col_list.index(col)].legend(loc="upper right")
        axs[col_list.index(col)].set_xlabel(col)
        axs[col_list.index(col)].set_ylabel('Count')
    
fig.show()

# %%
df_K_p2.describe()
# Out:
#          Population  Median_income  HH_apt_LH_rise  HH_dwelling_other  \
# count   4980.000000    4980.000000     4980.000000        4980.000000
# mean    4886.455622   77551.276643      780.309639          15.859438
# std     2477.749372   33076.778994      891.444026          63.067512
# min        2.000000   11334.980000        0.000000           0.000000
# 25%     3305.000000   53201.355000      148.000000           0.000000
# 50%     4663.500000   76328.300000      490.000000           2.000000
# 75%     6242.500000   95554.435000     1120.250000           6.000000
# max    30789.000000  669559.560000    15248.000000        1378.000000
#
#        Dwellings_renter  Avg_HH_size  Total_before_2005  HH_not_tenure  \
# count       4980.000000  4980.000000        4980.000000    4980.000000
# mean         630.678514     2.577107        1207.259839     117.290562
# std          594.149831     0.918424         705.341299     116.063251
# min            0.000000     1.000000           0.000000     -57.000000
# 25%          202.750000     2.217237         729.250000      55.000000
# 50%          458.000000     2.539718        1214.000000      98.000000
# 75%          880.250000     2.850387        1667.000000     150.000000
# max         6813.000000    49.250000        5407.000000    3497.000000
#
#            Cluster
# count  4980.000000
# mean      0.667871
# std       0.794217
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       2.000000

# %%
# count summary
count_summary = df_K_p2.describe().loc[['count']]

for n in range(0,cluster_number):
    index = pd.Index([n])
    temp = df_K_p2[df_K_p2['Cluster']==n].describe().loc[['count']].set_index(index)
    count_summary = pd.concat([count_summary, temp])

count_summary
# Out:
#        Population  Median_income  HH_apt_LH_rise  HH_dwelling_other  \
# count      4980.0         4980.0          4980.0             4980.0
# 0          2672.0         2672.0          2672.0             2672.0
# 1          1290.0         1290.0          1290.0             1290.0
# 2          1018.0         1018.0          1018.0             1018.0
#
#        Dwellings_renter  Avg_HH_size  Total_before_2005  HH_not_tenure  \
# count            4980.0       4980.0             4980.0         4980.0
# 0                2672.0       2672.0             2672.0         2672.0
# 1                1290.0       1290.0             1290.0         1290.0
# 2                1018.0       1018.0             1018.0         1018.0
#
#        Cluster
# count   4980.0
# 0       2672.0
# 1       1290.0
# 2       1018.0

# %%
# mean summary
mean_summary = df_K_p2.describe().loc[['mean']]

for n in range(0,cluster_number):
    index = pd.Index([n])
    temp = df_K_p2[df_K_p2['Cluster']==n].describe().loc[['mean']].set_index(index)
    mean_summary = pd.concat([mean_summary, temp])

mean_summary
# Out:
#        Population  Median_income  HH_apt_LH_rise  HH_dwelling_other  \
# mean  4886.455622   77551.276643      780.309639          15.859438
# 0     3348.157186   79936.470221      411.477919           9.063623
# 1     7326.620930   92280.980527      516.597674          35.479845
# 2     5831.956778   52625.387397     2082.575639           8.833988
#
#       Dwellings_renter  Avg_HH_size  Total_before_2005  HH_not_tenure  \
# mean        630.678514     2.577107        1207.259839     117.290562
# 0           368.248503     2.570362         926.489895      65.821482
# 1           455.493023     2.947989        1168.109302     180.473643
# 2          1541.486248     2.124835        1993.823183     172.319253
#
#        Cluster
# mean  0.667871
# 0     0.000000
# 1     1.000000
# 2     2.000000

# %%
# cluster count bar chart
temp = count_summary.iloc[1:,:]['Population']
fig, ax = plt.subplots(1, figsize=(5, 4))
ax.bar(temp.index.astype(str), temp)
ax.set_xlabel('Cluster')
ax.set_ylabel('Count')
fig.show()

# %%
fig, axs = plt.subplots(len(col_list)-1, figsize=(5, 50))
# plt.subplots_adjust(hspace=1)
for col in col_list:
    if col != "Cluster":

        axs[col_list.index(col)].bar(mean_summary[col].index.astype(str), mean_summary[col], alpha=0.4)
        axs[col_list.index(col)].set_xlabel(col)
        axs[col_list.index(col)].set_ylabel('Mean Value')
    
fig.show()

# %% [markdown]
# # 4. Split Dataset

# %%
test_size = 0.3

# %%
df_K_p2.reset_index(drop=True, inplace=True)

# %%
enc = OneHotEncoder(handle_unknown='ignore')
enc_df = pd.DataFrame(enc.fit_transform(df_K_p2[['Cluster']]).toarray())
enc_df.columns = enc.get_feature_names_out(['Cluster'])

# %%
joined_df = df_K_p2.join(enc_df)
joined_df.drop(columns=['Cluster'], inplace=True)

# %%
df.columns
# Out:
# Index(['Population', 'Median_income', 'HH_apt_LH_rise', 'HH_dwelling_other',
#        'Dwellings_renter', 'Avg_HH_size', 'Total_before_2005',
#        'HH_not_tenure'],
#       dtype='object')

# %%
columns = ['Population', 'Avg_HH_size', 'Total_before_2005',
        'HH_apt_LH_rise', 'HH_dwelling_other',
       'HH_not_tenure', 'Dwellings_renter', 'Cluster_0',
       'Cluster_1', 'Median_income']
joined_df = joined_df[columns]

# %%
joined_array = joined_df.to_numpy()
X = joined_array[:,:-1]
y = joined_array[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = test_size)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3486, 9), (1494, 9), (3486,), (1494,))

# %%
scaler = StandardScaler().fit(X_train[:,:-3])
rescaled_X_train = scaler.transform(X_train[:,:-3])
rescaled_X_train = np.concatenate((rescaled_X_train, X_train[:,-3:]), axis=1)

# %% [markdown]
# # 5. Building Models for Prediction

# %%
# Build K Fold
num_folds = 10
# kfold=KFold(n_splits = num_folds, shuffle = True, random_state = seed)
# kfold.get_n_splits(X_train)
# print(kfold)

# %% [markdown]
# # 5.1 KNN

# %%
# Build grid
# Here we use accuracy as the scoring metrics

knn_scoring = 'neg_mean_absolute_error'
k_values = np.arange(1,50)
knn_param_grid = dict(n_neighbors = k_values, weights = ["distance", "uniform"])

# %%
knn_model = KNeighborsRegressor()
knn_grid = GridSearchCV(estimator = knn_model, param_grid = knn_param_grid, scoring = knn_scoring, cv= num_folds)
knn_grid_result = knn_grid.fit(rescaled_X_train, y_train)

# %%
print(f"Best: {knn_grid_result.best_score_} {knn_grid_result.best_params_}" )
# Out:
# Best: -16670.414443500344 {'n_neighbors': 10, 'weights': 'distance'}

# %%
grid_result = knn_grid_result

# %%
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']

# %%
dist_mean = list()
dist_stds = list()
uni_mean = list()
uni_stds = list()
dist_n_n_index = list()
uni_n_n_index = list()

for i in range(len(means)):
    
    if params[i]['weights'] == "distance":
        dist_mean.append(means[i])
        dist_stds.append(stds[i])
        dist_n_n_index.append(params[i]['n_neighbors'])
        
    elif params[i]['weights'] == "uniform":
        uni_mean.append(means[i])
        uni_stds.append(stds[i])
        uni_n_n_index.append(params[i]['n_neighbors'])

# %%
# Plot score mean vs k neighbours, using distance
plt.plot(dist_n_n_index, dist_mean)

# %%
# Plot score stds vs k neighbours, using distance
plt.plot(dist_n_n_index, dist_stds)

# %%
# Plot score mean vs k neighbours, using uniform
plt.plot(uni_n_n_index, uni_mean)

# %%
# Plot score stds vs k neighbours, using uniform
plt.plot(uni_n_n_index, uni_stds)

# %%
best_n_neighbour = knn_grid_result.best_params_['n_neighbors']
best_weights = knn_grid_result.best_params_['weights']

# %%
knn_trained_model = KNeighborsRegressor(n_neighbors = best_n_neighbour, weights=best_weights)
knn_trained_model.fit(rescaled_X_train,y_train)

rescaled_X_test = scaler.transform(X_test[:,:-3])
rescaled_X_test = np.concatenate((rescaled_X_test, X_test[:,-3:]), axis=1)

y_pred = knn_trained_model.predict(rescaled_X_test)
mean_absolute_error(y_test, y_pred)
# Out:
# 16781.9318787304

# %% [markdown]
# # 5.2 KNN with Segmentation

# %%
df_K_p2 = df_K_p2[['Population', 'Avg_HH_size', 'Total_before_2005', 'HH_apt_LH_rise', 'HH_dwelling_other',
       'HH_not_tenure', 'Dwellings_renter', 'Cluster', 'Median_income']]

# %%
df_K_p2_array = df_K_p2.to_numpy()
X_s = df_K_p2_array[:,:-1]
y_s = df_K_p2_array[:,-1]
X_train_s, X_test_s, y_train_s, y_test_s = train_test_split(X_s, y_s, test_size = test_size)

# %%
train_s = pd.DataFrame(X_train_s)
train_s.columns = ['Population', 'Avg_HH_size', 'Total_before_2005', 
       'HH_apt_LH_rise', 'HH_dwelling_other', 'HH_not_tenure',
        'Dwellings_renter', 'Cluster']
train_s['Median_income'] = y_train_s

# %%
df_p2_dict = {}
df_p2_y_dict = {}
df_p2_scaler_dict = {}
df_p2_scaled_x_dict = {}
df_p2_best_dict = {}
    
knn_scoring = 'neg_mean_absolute_error'
k_values = np.arange(1,50)


for i in range(0,3):
    df_p2_dict[i] = pd.DataFrame()
    df_p2_dict[i] = train_s[train_s['Cluster']==i].copy(deep=True)
    df_p2_y_dict[i] = train_s[train_s['Cluster']==i]['Median_income'].copy(deep=True)
    df_p2_y_dict[i] = df_p2_y_dict[i].to_numpy()
    df_p2_dict[i].drop(columns=['Cluster', 'Median_income'], inplace=True)
    
    scaler_s = StandardScaler().fit(df_p2_dict[i])
    df_p2_scaler_dict[i] = scaler_s
    scaled_X_s = scaler_s.transform(df_p2_dict[i])
    df_p2_scaled_x_dict[i] = scaled_X_s

    knn_param_grid = dict(n_neighbors = k_values, weights = ["distance", "uniform"])
    
    knn_model_s = KNeighborsRegressor()
    knn_grid_s = GridSearchCV(estimator = knn_model_s, param_grid = knn_param_grid, scoring = knn_scoring, cv= num_folds)
    knn_grid_result_s = knn_grid_s.fit(scaled_X_s, df_p2_y_dict[i])
    df_p2_best_dict[i] = {'score': knn_grid_result_s.best_score_,
                         'parameters': knn_grid_result_s.best_params_,
                         'cv_results_': knn_grid_result_s.cv_results_}

# %%
for a in range(0,3):
    print(df_p2_best_dict[a]['parameters'])
    print(df_p2_best_dict[a]['score'])
# Out:
# {'n_neighbors': 20, 'weights': 'distance'}
# -15506.948247403556
# {'n_neighbors': 32, 'weights': 'distance'}
# -12937.642229278088
# {'n_neighbors': 19, 'weights': 'distance'}
# -9648.657174755554

# %%
test_s = pd.DataFrame(X_test_s)
test_s.columns = ['Population', 'Avg_HH_size', 'Total_before_2005', 
       'HH_apt_LH_rise', 'HH_dwelling_other', 'HH_not_tenure',
       'Dwellings_renter', 'Cluster']
test_s['Median_income'] = y_test_s

# %%
df_p2_test_dict = {}
df_p2_test_y_dict = {}
df_p2_test_result_dict = {}
df_p2_test_preds_dict = {}

for i in range(0,3):
    df_p2_test_dict[i] = pd.DataFrame()
    df_p2_test_dict[i] = test_s[test_s['Cluster']==i].copy(deep=True)
    df_p2_test_y_dict[i] = test_s[test_s['Cluster']==i]['Median_income'].copy(deep=True)
    df_p2_test_y_dict[i] = df_p2_test_y_dict[i].to_numpy()
    df_p2_test_dict[i].drop(columns=['Cluster', 'Median_income'], inplace=True)
    

    scaled_X_s = df_p2_scaler_dict[i].transform(df_p2_test_dict[i])
    
    knn_model_s = KNeighborsRegressor(n_neighbors = df_p2_best_dict[i]['parameters']['n_neighbors'], 
                                      weights = df_p2_best_dict[i]['parameters']['weights'])
    
    knn_model_s.fit(df_p2_scaled_x_dict[i], df_p2_y_dict[i])
    
    y_pred_s = knn_model_s.predict(scaled_X_s)
    
    df_p2_test_result_dict[i] = mean_absolute_error(df_p2_test_y_dict[i], y_pred_s)
    df_p2_test_preds_dict[i] = y_pred_s

# %%
df_p2_test_result_dict
# Out:
# {0: 15202.920374919115, 1: 11976.795036708452, 2: 9117.882561691627}

# %%
knn_seg_dict = {"df_p2_dict": df_p2_dict,
               'df_p2_y_dict': df_p2_y_dict,
               'df_p2_scaler_dict': df_p2_scaler_dict,
               'df_p2_scaled_x_dict': df_p2_scaled_x_dict,
               'df_p2_best_dict': df_p2_best_dict,
               'df_p2_test_dict': df_p2_test_dict,
               'df_p2_test_y_dict': df_p2_test_y_dict,
               'df_p2_test_result_dict': df_p2_test_result_dict,
               'df_p2_test_preds_dict': df_p2_test_preds_dict}

# %%
knn_all_preds = []
knn_all_testys = []
for i in range(0,3):
    knn_all_preds = knn_all_preds + list(knn_seg_dict['df_p2_test_preds_dict'][i])
    knn_all_testys = knn_all_testys + list(knn_seg_dict['df_p2_test_y_dict'][i])
    
mean_absolute_error(knn_all_testys, knn_all_preds)
# Out:
# 13153.979713270568

# %% [markdown]
# # 5.3 Random Forest

# %%
num_folds = 10
rf_scoring = 'neg_mean_absolute_error'
min_samples_leaf = np.arange(1,50,5)
n_estimators = np.arange(40,100,20)
rf_param_grid = dict(min_samples_leaf = min_samples_leaf, n_estimators = n_estimators)

# %%
regr = RandomForestRegressor(random_state=seed)
rf_grid = GridSearchCV(estimator = regr, param_grid = rf_param_grid, scoring = rf_scoring, cv= num_folds)
rf_grid_result = rf_grid.fit(X_train, y_train)

# %%
print(f"Best: {rf_grid_result.best_score_} {rf_grid_result.best_params_}" )
# Out:
# Best: -13037.927556325925 {'min_samples_leaf': 11, 'n_estimators': 80}

# %%
grid_result = knn_grid_result

# %%
best_min_samples_leaf = rf_grid_result.best_params_['min_samples_leaf']
best_n_estimators = rf_grid_result.best_params_['n_estimators']

# %%
regr_trained_model = RandomForestRegressor(random_state=seed, verbose=1)
regr_trained_model.fit(X_train,y_train)

y_pred = regr_trained_model.predict(X_test)
mean_absolute_error(y_test, y_pred)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.9s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# 13235.606681860774

# %% [markdown]
# # 5.4 Random Forest with Segmentation

# %%
df_K_p2 = df_K_p2[['Population', 'Avg_HH_size', 'Total_before_2005',
        'HH_apt_LH_rise', 'HH_dwelling_other',
       'HH_not_tenure', 'Dwellings_renter', 'Cluster', 'Median_income']]

# %%
df_K_p2_array = df_K_p2.to_numpy()
X_s = df_K_p2_array[:,:-1]
y_s = df_K_p2_array[:,-1]
X_train_s, X_test_s, y_train_s, y_test_s = train_test_split(X_s, y_s, test_size = test_size)

# %%
train_s = pd.DataFrame(X_train_s)
train_s.columns = ['Population', 'Avg_HH_size', 'Total_before_2005',
       'HH_apt_LH_rise', 'HH_dwelling_other', 'HH_not_tenure',
        'Dwellings_renter', 'Cluster']
train_s['Median_income'] = y_train_s

# %%
df_p2_dict = {}
df_p2_y_dict = {}
df_p2_scaler_dict = {}
df_p2_scaled_x_dict = {}
df_p2_best_dict = {}
    
rf_scoring = 'neg_mean_absolute_error'
min_samples_leaf = np.arange(1,50,5)
n_estimators = np.arange(40,100,20)
rf_param_grid = dict(min_samples_leaf = min_samples_leaf, n_estimators = n_estimators)


for i in range(0,3):
    df_p2_dict[i] = pd.DataFrame()
    df_p2_dict[i] = train_s[train_s['Cluster']==i].copy(deep=True)
    df_p2_y_dict[i] = train_s[train_s['Cluster']==i]['Median_income'].copy(deep=True)
    df_p2_y_dict[i] = df_p2_y_dict[i].to_numpy()
    df_p2_dict[i].drop(columns=['Cluster', 'Median_income'], inplace=True)
    

    rf_param_grid = dict(min_samples_leaf = min_samples_leaf, n_estimators = n_estimators)
    
    regr_s = RandomForestRegressor(random_state=seed)
    rf_grid_s = GridSearchCV(estimator = regr_s, param_grid = rf_param_grid, scoring = rf_scoring, cv= num_folds)
    rf_grid_result_s = rf_grid_s.fit(df_p2_dict[i], df_p2_y_dict[i])
    
    df_p2_best_dict[i] = {'score': rf_grid_result_s.best_score_,
                     'parameters': rf_grid_result_s.best_params_}

# %%
df_p2_best_dict
# Out:
# {0: {'score': -14300.553513889847,
#   'parameters': {'min_samples_leaf': 6, 'n_estimators': 80}},
#  1: {'score': -12395.430147157786,
#   'parameters': {'min_samples_leaf': 6, 'n_estimators': 80}},
#  2: {'score': -9472.307888218245,
#   'parameters': {'min_samples_leaf': 6, 'n_estimators': 60}}}

# %%
test_s = pd.DataFrame(X_test_s)
test_s.columns = ['Population', 'Avg_HH_size', 'Total_before_2005', 
       'HH_apt_LH_rise', 'HH_dwelling_other', 'HH_not_tenure',
        'Dwellings_renter', 'Cluster']
test_s['Median_income'] = y_test_s

# %%
df_p2_test_dict = {}
df_p2_test_y_dict = {}
df_p2_test_result_dict = {}
df_p2_test_preds_dict = {}

for i in range(0,3):
    df_p2_test_dict[i] = pd.DataFrame()
    df_p2_test_dict[i] = test_s[test_s['Cluster']==i].copy(deep=True)
    df_p2_test_y_dict[i] = test_s[test_s['Cluster']==i]['Median_income'].copy(deep=True)
    df_p2_test_y_dict[i] = df_p2_test_y_dict[i].to_numpy()
    df_p2_test_dict[i].drop(columns=['Cluster', 'Median_income'], inplace=True)
    
    
    rf_model_s = RandomForestRegressor(min_samples_leaf = df_p2_best_dict[i]['parameters']['min_samples_leaf'],
                                      n_estimators = df_p2_best_dict[i]['parameters']['n_estimators'])
    
    rf_model_s.fit(df_p2_dict[i], df_p2_y_dict[i])
    
    y_pred_s = rf_model_s.predict(df_p2_test_dict[i])
    df_p2_test_preds_dict[i] = y_pred_s
    
    df_p2_test_result_dict[i] = mean_absolute_error(df_p2_test_y_dict[i], y_pred_s)

# %%
df_p2_test_result_dict
# Out:
# {0: 15378.418595830619, 1: 12722.587844836933, 2: 8896.074850577961}

# %%
rf_seg_dict = {"df_p2_dict": df_p2_dict,
               'df_p2_y_dict': df_p2_y_dict,
               'df_p2_scaler_dict': df_p2_scaler_dict,
               'df_p2_scaled_x_dict': df_p2_scaled_x_dict,
               'df_p2_best_dict': df_p2_best_dict,
               'df_p2_test_dict': df_p2_test_dict,
               'df_p2_test_y_dict': df_p2_test_y_dict,
               'df_p2_test_result_dict': df_p2_test_result_dict,
               'df_p2_test_preds_dict': df_p2_test_preds_dict}

# %%
rf_all_preds = []
rf_all_testys = []
for i in range(0,3):
    rf_all_preds = rf_all_preds + list(rf_seg_dict['df_p2_test_preds_dict'][i])
    rf_all_testys = rf_all_testys + list(rf_seg_dict['df_p2_test_y_dict'][i])
    
mean_absolute_error(rf_all_testys, rf_all_preds)
# Out:
# 13384.027096175645

# %% [markdown]
# # 5.5 Linear Regression

# %%
lr = LinearRegression()
lr_fit = lr.fit(X_train, y_train)

# %%
pred_train_lr= lr.predict(X_train)
print(mean_absolute_error(y_train,pred_train_lr))


pred_test_lr= lr.predict(X_test)
print(mean_absolute_error(y_test,pred_test_lr))
# Out:
# 15678.82255039341
# 16218.215554279674

# %%
rr = Ridge(alpha=0.01)
rr.fit(X_train, y_train) 
pred_train_rr= rr.predict(X_train)
print(mean_absolute_error(y_train,pred_train_rr))


pred_test_rr= rr.predict(X_test)
print(mean_absolute_error(y_test,pred_test_rr))
# Out:
# 15678.82322704459
# 16218.20857173979

# %%
model_lasso = Lasso(alpha=0.01)
model_lasso.fit(X_train, y_train) 
pred_train_lasso= model_lasso.predict(X_train)
print(mean_absolute_error(y_train,pred_train_lasso))


pred_test_lasso= model_lasso.predict(X_test)
print(mean_absolute_error(y_test,pred_test_lasso))
# Out:
# 15678.823154660986
# 16218.212226137292

# %% [markdown]
# # 5.6 Linear Regression with segmentation

# %%
# Build grid
# Here we use accuracy as the scoring metrics

lr_scoring = 'neg_mean_absolute_error'
alpha = np.arange(0.01, 0.07, 0.01)
ls_param_grid = dict(alpha = alpha)

# %%
df_K_p2 = df_K_p2[['Population', 'Avg_HH_size', 'Total_before_2005', 'HH_apt_LH_rise', 'HH_dwelling_other',
       'HH_not_tenure', 'Dwellings_renter', 'Cluster', 'Median_income']]

# %%
df_K_p2_array = df_K_p2.to_numpy()
X_s = df_K_p2_array[:,:-1]
y_s = df_K_p2_array[:,-1]
X_train_s, X_test_s, y_train_s, y_test_s = train_test_split(X_s, y_s, test_size = test_size)

# %%
train_s = pd.DataFrame(X_train_s)
train_s.columns = ['Population', 'Avg_HH_size', 'Total_before_2005', 
       'HH_apt_LH_rise', 'HH_dwelling_other', 'HH_not_tenure',
        'Dwellings_renter', 'Cluster']
train_s['Median_income'] = y_train_s

# %%
df_p2_dict = {}
df_p2_y_dict = {}
df_p2_scaler_dict = {}
df_p2_scaled_x_dict = {}
df_p2_best_dict = {}
    
lr_scoring = 'neg_mean_absolute_error'
k_values = np.arange(1,50)


for i in range(0,3):
    df_p2_dict[i] = pd.DataFrame()
    df_p2_dict[i] = train_s[train_s['Cluster']==i].copy(deep=True)
    df_p2_y_dict[i] = train_s[train_s['Cluster']==i]['Median_income'].copy(deep=True)
    df_p2_y_dict[i] = df_p2_y_dict[i].to_numpy()
    df_p2_dict[i].drop(columns=['Cluster', 'Median_income'], inplace=True)
    
    scaler_s = StandardScaler().fit(df_p2_dict[i])
    df_p2_scaler_dict[i] = scaler_s
    scaled_X_s = scaler_s.transform(df_p2_dict[i])
    df_p2_scaled_x_dict[i] = scaled_X_s

    ls_param_grid = dict(alpha = alpha)
    
    ls_model_s = linear_model.Lasso()
    ls_grid_s = GridSearchCV(estimator = ls_model_s, param_grid = ls_param_grid, scoring = lr_scoring, cv= num_folds)
    ls_grid_result_s = ls_grid_s.fit(scaled_X_s, df_p2_y_dict[i])
    df_p2_best_dict[i] = {'score': ls_grid_result_s.best_score_,
                         'parameters': ls_grid_result_s.best_params_,
                         'cv_results_': ls_grid_result_s.cv_results_}

# %%
for a in range(0,3):
    print(df_p2_best_dict[a]['parameters'])
    print(df_p2_best_dict[a]['score'])
# Out:
# {'alpha': 0.060000000000000005}
# -16155.615138491537
# {'alpha': 0.060000000000000005}
# -13351.057141717625
# {'alpha': 0.060000000000000005}
# -9340.750755591736

# %%
test_s = pd.DataFrame(X_test_s)
test_s.columns = ['Population', 'Avg_HH_size', 'Total_before_2005', 
       'HH_apt_LH_rise', 'HH_dwelling_other', 'HH_not_tenure',
       'Dwellings_renter', 'Cluster']
test_s['Median_income'] = y_test_s

# %%
df_p2_test_dict = {}
df_p2_test_y_dict = {}
df_p2_test_result_dict = {}
df_p2_test_coef_dict = {}
df_p2_test_preds_dict = {}

for i in range(0,3):
    df_p2_test_dict[i] = pd.DataFrame()
    df_p2_test_dict[i] = test_s[test_s['Cluster']==i].copy(deep=True)
    df_p2_test_y_dict[i] = test_s[test_s['Cluster']==i]['Median_income'].copy(deep=True)
    df_p2_test_y_dict[i] = df_p2_test_y_dict[i].to_numpy()
    df_p2_test_dict[i].drop(columns=['Cluster', 'Median_income'], inplace=True)
    

    scaled_X_s = df_p2_scaler_dict[i].transform(df_p2_test_dict[i])
    
    ls_model_s = linear_model.Lasso(alpha = df_p2_best_dict[i]['parameters']['alpha'])
    
    ls_model_s.fit(df_p2_scaled_x_dict[i], df_p2_y_dict[i])
    
    y_pred_s = ls_model_s.predict(scaled_X_s)
    df_p2_test_coef_dict[i] = ls_model_s.sparse_coef_
    df_p2_test_preds_dict[i] = y_pred_s

    
    df_p2_test_result_dict[i] = mean_absolute_error(df_p2_test_y_dict[i], y_pred_s)

# %%
df_p2_test_result_dict
# Out:
# {0: 15439.072910602794, 1: 13872.156609461601, 2: 9134.371879312175}

# %%
ls_seg_dict = {"df_p2_dict": df_p2_dict,
               'df_p2_y_dict': df_p2_y_dict,
               'df_p2_scaler_dict': df_p2_scaler_dict,
               'df_p2_scaled_x_dict': df_p2_scaled_x_dict,
               'df_p2_best_dict': df_p2_best_dict,
               'df_p2_test_dict': df_p2_test_dict,
               'df_p2_test_y_dict': df_p2_test_y_dict,
               'df_p2_test_result_dict': df_p2_test_result_dict,
               'df_p2_test_coef_dict': df_p2_test_coef_dict,
               'df_p2_test_preds_dict': df_p2_test_preds_dict}

# %%
ls_all_preds = []
ls_all_testys = []
for i in range(0,3):
    ls_all_preds = ls_all_preds + list(ls_seg_dict['df_p2_test_preds_dict'][i])
    ls_all_testys = ls_all_testys + list(ls_seg_dict['df_p2_test_y_dict'][i])
    
mean_absolute_error(ls_all_testys, ls_all_preds)
# Out:
# 13814.649690868193

# %%
test_s.columns
# Out:
# Index(['Population', 'Avg_HH_size', 'Total_before_2005', 'HH_apt_LH_rise',
#        'HH_dwelling_other', 'HH_not_tenure', 'Dwellings_renter', 'Cluster',
#        'Median_income'],
#       dtype='object')

# %%
for i in range(0,3):
    display(pd.DataFrame.sparse.from_spmatrix(ls_seg_dict['df_p2_test_coef_dict'][i]))
# Out:
#              0            1            2           3            4  \
# 0  9857.177563  2199.239329 -1173.980946 -1546.36748 -2160.793503
#
#              5             6
# 0  2062.295749 -17182.877773
#              0            1            2            3           4           5  \
# 0  5207.368883 -2350.005976 -3250.892602 -3679.781084 -2683.69301 -326.435656
#
#              6
# 0 -8396.329434
#              0            1            2            3            4  \
# 0  9110.881344 -5004.673841  2308.693794  1278.162365 -1995.432358
#
#              5             6
# 0  2271.544065 -13583.998951

# %% [markdown]
# # 6. Prediction

# %%
test_original_df = pd.read_csv("CensusCanada2016Test.csv")
test_df = test_original_df.copy(deep=True)

# %%
new_test_col_names = ['Population',
                     'Households',
                     'HH_construction',
                     'HH_before_1961',
                     'HH_1961_1980',
                     'HH_1981_1990',
                     'HH_1991_2000',
                     'HH_2001_2005',
                     'HH_houses',
                     'HH_apt_LH_rise',
                     'HH_dwelling_other',
                     'HH_tenure',
                     'Dwellings_owner',
                     'Dwellings_renter']

# %%
test_df.columns = new_test_col_names
test_df.head()
# Out:
#    Population  Households  HH_construction  HH_before_1961  HH_1961_1980  \
# 0        2692         893              893              15            21
# 1        3884        1511             1511              17           839
# 2        7014        2768             2768             767           615
# 3        9136        4577             4577            1540           969
# 4        3614        1167             1167              44            94
#
#    HH_1981_1990  HH_1991_2000  HH_2001_2005  HH_houses  HH_apt_LH_rise  \
# 0            46           648           114        883              10
# 1           218            27            33       1025             486
# 2           223           435           166       1390            1378
# 3           437           244           457       2102            2461
# 4            34           115           184       1069              98
#
#    HH_dwelling_other  HH_tenure  Dwellings_owner  Dwellings_renter
# 0                  0        836              790                46
# 1                  0       1399             1207               192
# 2                  0       2552             1533              1019
# 3                 14       4232             2402              1830
# 4                  0       1080             1042                38

# %%
zero_HH_df = test_df[test_df['Households']==0].copy(deep=True)
zero_HH_df
# Out:
#      Population  Households  HH_construction  HH_before_1961  HH_1961_1980  \
# 25            0           0                0               0             0
# 27            0           0                0               0             0
# 229           0           0                0               0             0
# 311           0           0                0               0             0
#
#      HH_1981_1990  HH_1991_2000  HH_2001_2005  HH_houses  HH_apt_LH_rise  \
# 25              0             0             0          0               0
# 27              0             0             0          0               0
# 229             0             0             0          0               0
# 311             0             0             0          0               0
#
#      HH_dwelling_other  HH_tenure  Dwellings_owner  Dwellings_renter
# 25                   0          0                0                 0
# 27                   0          0                0                 0
# 229                  0          0                0                 0
# 311                  0          0                0                 0

# %%
# drop rows with households equal 0. 
test_df.drop(test_df[test_df['Households']==0].index, inplace=True)

test_df['Avg_HH_size'] = test_df['Population']/test_df['Households']

#Bucket construction before 2000
test_df['Total_before_2005'] = test_df['HH_1981_1990'] + test_df['HH_1961_1980'] + test_df['HH_before_1961']

test_df['HH_not_tenure'] = test_df['Households']-test_df['HH_tenure']

# %%
# drop HH_construction because it's the same as households
dropped_columns = ['HH_construction', 'Households', 'HH_before_1961', 'HH_1961_1980', 'HH_1981_1990',
                  'HH_1991_2000', 'HH_2001_2005', 'HH_tenure']
test_df.drop(columns=dropped_columns, inplace=True)
test_df.head()
# Out:
#    Population  HH_houses  HH_apt_LH_rise  HH_dwelling_other  Dwellings_owner  \
# 0        2692        883              10                  0              790
# 1        3884       1025             486                  0             1207
# 2        7014       1390            1378                  0             1533
# 3        9136       2102            2461                 14             2402
# 4        3614       1069              98                  0             1042
#
#    Dwellings_renter  Avg_HH_size  Total_before_2005  HH_not_tenure
# 0                46     3.014558                 82             57
# 1               192     2.570483               1074            112
# 2              1019     2.533960               1605            216
# 3              1830     1.996067               2946            345
# 4                38     3.096829                172             87

# %%
# drop HH_construction because it's the same as households
dropped_columns = ['HH_houses', 'Dwellings_owner']
test_df.drop(columns=dropped_columns, inplace=True)

# %% [markdown]
# Scale the data.

# %%
index_keeper = []
index_keeper = list(test_df.index)

# %%
test_df['Median_income'] = 0

test_df = test_df[['Population', 'Median_income', 'HH_apt_LH_rise', 'HH_dwelling_other', 'Dwellings_renter',
       'Avg_HH_size', 'Total_before_2005', 'HH_not_tenure']]

# %%
scaled_test_df = kmeans_scaler.transform(test_df)
scaled_test_df = pd.DataFrame(scaled_test_df)
scaled_test_df.columns = test_df.columns
scaled_test_df.drop(columns = ['Median_income'], inplace = True)
scaled_test_df.head()
# Out:
#    Population  HH_apt_LH_rise  HH_dwelling_other  Dwellings_renter  \
# 0   -0.885754       -0.864201          -0.251493         -0.984158
# 1   -0.404624       -0.330182          -0.251493         -0.738404
# 2    0.858746        0.670542          -0.251493          0.653641
# 3    1.715255        1.885546          -0.029486          2.018753
# 4   -0.513605       -0.765475          -0.251493         -0.997624
#
#    Avg_HH_size  Total_before_2005  HH_not_tenure
# 0     0.476353          -1.595501      -0.519515
# 1    -0.007213          -0.188949      -0.045588
# 2    -0.046985           0.563954       0.850565
# 3    -0.632712           2.465352       1.962140
# 4     0.565941          -1.467891      -0.261009

# %%
np.random.seed(seed)

# Fit model to scaled_df
K_Mean_for_pred.predict(scaled_test_df)

test_df['Cluster'] = K_Mean_for_pred.predict(scaled_test_df)
test_df.drop(columns = ['Median_income'], inplace = True)

# %%
df_K_p2_array = df_K_p2.to_numpy()
X_s = df_K_p2_array[:,:-1]
y_s = df_K_p2_array[:,-1]

# %%
# Train KNN based on all training data using the best parameters

all_dict = {}
all_y_dict = {}
all_scaler_dict = {}
all_scaled_x_dict = {}
all_best_dict = {}
all_model_dict = {}
all_score_dict = {}
    
for i in range(0,3):
    all_dict[i] = pd.DataFrame()
    all_dict[i] = df_K_p2[df_K_p2['Cluster']==i].copy(deep=True)
    all_y_dict[i] = df_K_p2[df_K_p2['Cluster']==i]['Median_income'].copy(deep=True)
    all_y_dict[i] = all_y_dict[i].to_numpy()
    all_dict[i].drop(columns=['Cluster', 'Median_income'], inplace=True)
    
    scaler_s = StandardScaler().fit(all_dict[i])
    all_scaler_dict[i] = scaler_s
    scaled_X_s = scaler_s.transform(all_dict[i])
    all_scaled_x_dict[i] = scaled_X_s

    final_n_neighbors = knn_seg_dict['df_p2_best_dict'][i]['parameters']['n_neighbors']
    final_weights = knn_seg_dict['df_p2_best_dict'][i]['parameters']['weights']
    
    final_model_s = KNeighborsRegressor(n_neighbors=final_n_neighbors,
                                       weights=final_weights)
    
    final_model_s.fit(scaled_X_s, all_y_dict[i])
    pred = final_model_s.predict(scaled_X_s)
    
    all_model_dict[i] = final_model_s
    display(all_y_dict[i])
    display(pred)

    all_score_dict[i] = {mean_absolute_error(all_y_dict[i], pred)}
# Out:
# array([ 68242.12,  88172.37,  91648.22, ..., 129048.12, 108823.38,
#         58258.26])
# array([ 68242.12,  88172.37,  91648.22, ..., 129048.12, 108823.38,
#         58258.26])
# array([103853.38,  82796.63, 189620.73, ...,  53758.01,  71370.58,
#        111457.48])
# array([103853.38,  82796.63, 189620.73, ...,  53758.01,  71370.58,
#        111457.48])
# array([44841.42, 52939.18, 46132.57, ..., 44627.85, 88129.09, 68735.64])
# array([44841.42, 52939.18, 46132.57, ..., 44627.85, 88129.09, 68735.64])

# %%
all_score_dict
# Out:
# {0: {8.696534431137724}, 1: {0.0}, 2: {0.0}}

# %%
test_data_dict = {}

for i in range(0, cluster_number):

    test_data_dict[i] = {}
    test_data_dict[i]['index'] = test_df[test_df["Cluster"]==i].index
    test_data_dict[i]['data'] = test_df[test_df["Cluster"]==i].copy(deep=True)
    test_data_dict[i]['data'].drop(columns=['Cluster'], inplace=True)
    test_data_dict[i]['data'] = test_data_dict[i]['data'][list(all_dict[i].columns)]
    
    scaled_X_final = all_scaler_dict[i].transform(test_data_dict[i]['data'])
    
    y_pred_final = all_model_dict[i].predict(scaled_X_final)
    test_data_dict[i]['pred'] = y_pred_final

# %%
pred_list = list()
index_list = list()
cluster_list = list()

for i in range(0, cluster_number):
    pred_list = pred_list + list(test_data_dict[i]['pred'])
    index_list = index_list + list(test_data_dict[i]['index'])
    cluster_list = cluster_list + [i]*len(test_data_dict[i]['pred'])

# %%
out_df = pd.DataFrame(list(zip(index_list, pred_list, cluster_list)), columns = ['Index', 'Prediction', 'Cluster'])

# %%
out_df
# Out:
#      Index     Prediction  Cluster
# 0        0  119626.385223        0
# 1        1  101040.199589        0
# 2        4  135832.969076        0
# 3        6   84732.260696        0
# 4        8  109585.808910        0
# ..     ...            ...      ...
# 712    707   38616.327400        2
# 713    708   54260.818355        2
# 714    712   50115.058154        2
# 715    715   55361.087765        2
# 716    717   41213.703283        2
#
# [717 rows x 3 columns]

# %%
zero_df = pd.DataFrame(list(zip(list(zero_HH_df.index), 
                                len(list(zero_HH_df.index))*[0], 
                                len(list(zero_HH_df.index))*[3])), columns = ['Index', 'Prediction', 'Cluster'])

# %%
zero_df
# Out:
#    Index  Prediction  Cluster
# 0     25           0        3
# 1     27           0        3
# 2    229           0        3
# 3    311           0        3

# %%
final_pred_df = pd.concat([out_df, zero_df])
final_pred_df.set_index("Index", inplace = True)
final_pred_df = final_pred_df.sort_index(ascending=True)
final_pred_df
# Out:
#           Prediction  Cluster
# Index
# 0      119626.385223        0
# 1      101040.199589        0
# 2       66753.665107        2
# 3       58857.192918        2
# 4      135832.969076        0
# ...              ...      ...
# 716     67956.995732        0
# 717     41213.703283        2
# 718     94733.178527        0
# 719    101131.258613        0
# 720     79706.048739        1
#
# [721 rows x 2 columns]
